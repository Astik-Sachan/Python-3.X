# %%
import pandas as pd

# %%
df = pd.read_csv('./My Uber Drives - 2016.csv')

# %%
df
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 0     01-01-2016 21:11  01-01-2016 21:17  Business       Fort Pierce
# 1     01-02-2016 01:25  01-02-2016 01:37  Business       Fort Pierce
# 2     01-02-2016 20:25  01-02-2016 20:38  Business       Fort Pierce
# 3     01-05-2016 17:31  01-05-2016 17:45  Business       Fort Pierce
# 4     01-06-2016 14:42  01-06-2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*         PURPOSE*
# 0          Fort Pierce      5.1   Meal/Entertain
# ...

# %%
df.head()
# Out:
#         START_DATE*         END_DATE* CATEGORY*       START*            STOP*  \
# 0  01-01-2016 21:11  01-01-2016 21:17  Business  Fort Pierce      Fort Pierce
# 1  01-02-2016 01:25  01-02-2016 01:37  Business  Fort Pierce      Fort Pierce
# 2  01-02-2016 20:25  01-02-2016 20:38  Business  Fort Pierce      Fort Pierce
# 3  01-05-2016 17:31  01-05-2016 17:45  Business  Fort Pierce      Fort Pierce
# 4  01-06-2016 14:42  01-06-2016 15:49  Business  Fort Pierce  West Palm Beach
#
#    MILES*         PURPOSE*
# 0     5.1   Meal/Entertain
# 1     5.0              NaN
# 2     4.8  Errand/Supplies
# 3     4.7          Meeting
# 4    63.7   Customer Visit

# %%
df.tail()
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*        PURPOSE*
# 1151  Unknown Location      3.9  Temporary Site
# 1152  Unknown Location     16.2         Meeting
# 1153           Gampaha      6.4  Temporary Site
# 1154         Ilukwatta     48.2  Temporary Site
# 1155               NaN  12204.7             NaN

# %%
df_newcsv = df.head()

# %%
df_newcsv.to_html('./dfasHTML.html')

# %%
df = pd.read_csv('./My Uber Drives - 2016.csv',sep='#')
df.head()
# Out:
#   START_DATE*,END_DATE*,CATEGORY*,START*,STOP*,MILES*,PURPOSE*
# 0  01-01-2016 21:11,01-01-2016 21:17,Business,For...
# 1  01-02-2016 01:25,01-02-2016 01:37,Business,For...
# 2  01-02-2016 20:25,01-02-2016 20:38,Business,For...
# 3  01-05-2016 17:31,01-05-2016 17:45,Business,For...
# 4  01-06-2016 14:42,01-06-2016 15:49,Business,For...

# %%
df = pd.read_csv('./My Uber Drives - 2016.csv',sep='#',skiprows=[0,3])
df.head() #Rows 0,3 are missing in head.
# Out:
#   01-01-2016 21:11,01-01-2016 21:17,Business,Fort Pierce,Fort Pierce,5.1,Meal/Entertain
# 0  01-02-2016 01:25,01-02-2016 01:37,Business,For...
# 1  01-05-2016 17:31,01-05-2016 17:45,Business,For...
# 2  01-06-2016 14:42,01-06-2016 15:49,Business,For...
# 3  01-06-2016 17:15,01-06-2016 17:19,Business,Wes...
# 4  01-06-2016 17:30,01-06-2016 17:35,Business,Wes...

# %%
df = pd.read_csv('./My Uber Drives - 2016.csv')
df.head()
# Out:
#         START_DATE*         END_DATE* CATEGORY*       START*            STOP*  \
# 0  01-01-2016 21:11  01-01-2016 21:17  Business  Fort Pierce      Fort Pierce
# 1  01-02-2016 01:25  01-02-2016 01:37  Business  Fort Pierce      Fort Pierce
# 2  01-02-2016 20:25  01-02-2016 20:38  Business  Fort Pierce      Fort Pierce
# 3  01-05-2016 17:31  01-05-2016 17:45  Business  Fort Pierce      Fort Pierce
# 4  01-06-2016 14:42  01-06-2016 15:49  Business  Fort Pierce  West Palm Beach
#
#    MILES*         PURPOSE*
# 0     5.1   Meal/Entertain
# 1     5.0              NaN
# 2     4.8  Errand/Supplies
# 3     4.7          Meeting
# 4    63.7   Customer Visit

# %%
df.describe() #description for all the numerical rows will be given
# Out:
#              MILES*
# count   1156.000000
# mean      21.115398
# std      359.299007
# min        0.500000
# 25%        2.900000
# 50%        6.000000
# 75%       10.400000
# max    12204.700000

# %%
df.dtypes
# Out:
# START_DATE*     object
# END_DATE*       object
# CATEGORY*       object
# START*          object
# STOP*           object
# MILES*         float64
# PURPOSE*        object
# dtype: object

# %%
type(df['START_DATE*'])
# Out:
# pandas.core.series.Series

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df[['START_DATE*','MILES*']]
# Out:
#            START_DATE*   MILES*
# 0     01-01-2016 21:11      5.1
# 1     01-02-2016 01:25      5.0
# 2     01-02-2016 20:25      4.8
# 3     01-05-2016 17:31      4.7
# 4     01-06-2016 14:42     63.7
# ...                ...      ...
# 1151  12/31/2016 13:24      3.9
# 1152  12/31/2016 15:03     16.2
# 1153  12/31/2016 21:32      6.4
# 1154  12/31/2016 22:08     48.2
# 1155            Totals  12204.7
#
# [1156 rows x 2 columns]

# %%
len(df)
# Out:
# 1156

# %%
import requests
user = []
res=requests.get('https://api.github.com/repos/pandas-dev/pandas/issues')
js=res.json()
for i in range(len(js)):
    user.append(js[i]['user'])
print(user)
print('='*100)
df1 = pd.DataFrame(user)
# Out:
# [{'login': 'MarcoGorelli', 'id': 33491632, 'node_id': 'MDQ6VXNlcjMzNDkxNjMy', 'avatar_url': 'https://avatars.githubusercontent.com/u/33491632?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/MarcoGorelli', 'html_url': 'https://github.com/MarcoGorelli', 'followers_url': 'https://api.github.com/users/MarcoGorelli/followers', 'following_url': 'https://api.github.com/users/MarcoGorelli/following{/other_user}', 'gists_url': 'https://api.github.com/users/MarcoGorelli/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/MarcoGorelli/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/MarcoGorelli/subscriptions', 'organizations_url': 'https://api.github.com/users/MarcoGorelli/orgs', 'repos_url': 'https://api.github.com/users/MarcoGorelli/repos', 'events_url': 'https://api.github.com/users/MarcoGorelli/events{/privacy}', 'received_events_url': 'https://api.github.com/users/MarcoGorelli/received_events', 'type': 'User', 'site_admin': False}, {'log
# ...

# %%
df1.columns
# Out:
# Index(['login', 'id', 'node_id', 'avatar_url', 'gravatar_id', 'url',
#        'html_url', 'followers_url', 'following_url', 'gists_url',
#        'starred_url', 'subscriptions_url', 'organizations_url', 'repos_url',
#        'events_url', 'received_events_url', 'type', 'site_admin'],
#       dtype='object')

# %%
dict_from_json = df1.to_dict()
print(dict_from_json)
# Out:
# {'login': {0: 'MarcoGorelli', 1: 'shyamsantoki', 2: 'ParfaitG', 3: 'mroeschke', 4: 'twoertwein', 5: 'QuentinBlampey', 6: 'warm200', 7: 'jorisvandenbossche', 8: 'jonashaag', 9: 'jonashaag', 10: 'jonashaag', 11: 'kamalsharma2', 12: 'spsspro', 13: 'phofl', 14: 'phofl', 15: 'joshdunnlime', 16: 'phofl', 17: 'jbrockmendel', 18: 'jbrockmendel', 19: 'jbrockmendel', 20: 'mroeschke', 21: 'phofl', 22: 'jbrockmendel', 23: 'TraverseTowner', 24: 'MarcoGorelli', 25: 'DonSeger', 26: 'MarcoGorelli', 27: 'oxlade39', 28: 'ChristopheBernard', 29: 'glemaitre'}, 'id': {0: 33491632, 1: 56479219, 2: 13602663, 3: 10647082, 4: 6618166, 5: 33903498, 6: 5666546, 7: 1020496, 8: 175722, 9: 175722, 10: 175722, 11: 88836971, 12: 94439026, 13: 61934744, 14: 61934744, 15: 89857735, 16: 61934744, 17: 8078968, 18: 8078968, 19: 8078968, 20: 10647082, 21: 61934744, 22: 8078968, 23: 16629450, 24: 33491632, 25: 94080584, 26: 33491632, 27: 144005, 28: 14012015, 29: 7454015}, 'node_id': {0: 'MDQ6VXNlcjMzNDkxNjMy', 1: 'MDQ6VX
# ...

# %%
dict_from_json.keys()
# Out:
# dict_keys(['login', 'id', 'node_id', 'avatar_url', 'gravatar_id', 'url', 'html_url', 'followers_url', 'following_url', 'gists_url', 'starred_url', 'subscriptions_url', 'organizations_url', 'repos_url', 'events_url', 'received_events_url', 'type', 'site_admin'])

# %%
dict_from_json['login']
# Out:
# {0: 'MarcoGorelli',
#  1: 'shyamsantoki',
#  2: 'ParfaitG',
#  3: 'mroeschke',
#  4: 'twoertwein',
#  5: 'QuentinBlampey',
#  6: 'warm200',
#  7: 'jorisvandenbossche',
#  8: 'jonashaag',
#  9: 'jonashaag',
#  10: 'jonashaag',
#  11: 'kamalsharma2',
#  12: 'spsspro',
#  13: 'phofl',
#  14: 'phofl',
#  15: 'joshdunnlime',
#  16: 'phofl',
#  17: 'jbrockmendel',
#  18: 'jbrockmendel',
#  19: 'jbrockmendel',
#  20: 'mroeschke',
#  21: 'phofl',
#  22: 'jbrockmendel',
#  23: 'TraverseTowner',
#  24: 'MarcoGorelli',
#  25: 'DonSeger',
#  26: 'MarcoGorelli',
#  27: 'oxlade39',
#  28: 'ChristopheBernard',
#  29: 'glemaitre'}

# %%
dict_from_json['id']
# Out:
# {0: 33491632,
#  1: 56479219,
#  2: 13602663,
#  3: 10647082,
#  4: 6618166,
#  5: 33903498,
#  6: 5666546,
#  7: 1020496,
#  8: 175722,
#  9: 175722,
#  10: 175722,
#  11: 88836971,
#  12: 94439026,
#  13: 61934744,
#  14: 61934744,
#  15: 89857735,
#  16: 61934744,
#  17: 8078968,
#  18: 8078968,
#  19: 8078968,
#  20: 10647082,
#  21: 61934744,
#  22: 8078968,
#  23: 16629450,
#  24: 33491632,
#  25: 94080584,
#  26: 33491632,
#  27: 144005,
#  28: 14012015,
#  29: 7454015}

# %%
json_data = pd.read_json("https://api.github.com/repos/pandas-dev/pandas/issues")
data = pd.DataFrame.from_records(json_data['user'])
data.head()
# Out:
#           login        id               node_id  \
# 0  MarcoGorelli  33491632  MDQ6VXNlcjMzNDkxNjMy
# 1  shyamsantoki  56479219  MDQ6VXNlcjU2NDc5MjE5
# 2      ParfaitG  13602663  MDQ6VXNlcjEzNjAyNjYz
# 3     mroeschke  10647082  MDQ6VXNlcjEwNjQ3MDgy
# 4    twoertwein   6618166  MDQ6VXNlcjY2MTgxNjY=
#
#                                           avatar_url gravatar_id  \
# 0  https://avatars.githubusercontent.com/u/334916...
# 1  https://avatars.githubusercontent.com/u/564792...
# 2  https://avatars.githubusercontent.com/u/136026...
# 3  https://avatars.githubusercontent.com/u/106470...
# 4  https://avatars.githubusercontent.com/u/661816...
#
#                                          url                         html_url  \
# 0  https://api.github.com/users/MarcoGorelli  https://github.com/MarcoGorelli
# 1  https://api.github.com/users/shyamsantoki  https://github.com/shyamsantoki
# 2      https://api.github.com/users/ParfaitG      https://github.com/ParfaitG
# ...

# %%
df.head()
# Out:
#         START_DATE*         END_DATE* CATEGORY*       START*            STOP*  \
# 0  01-01-2016 21:11  01-01-2016 21:17  Business  Fort Pierce      Fort Pierce
# 1  01-02-2016 01:25  01-02-2016 01:37  Business  Fort Pierce      Fort Pierce
# 2  01-02-2016 20:25  01-02-2016 20:38  Business  Fort Pierce      Fort Pierce
# 3  01-05-2016 17:31  01-05-2016 17:45  Business  Fort Pierce      Fort Pierce
# 4  01-06-2016 14:42  01-06-2016 15:49  Business  Fort Pierce  West Palm Beach
#
#    MILES*         PURPOSE*
# 0     5.1   Meal/Entertain
# 1     5.0              NaN
# 2     4.8  Errand/Supplies
# 3     4.7          Meeting
# 4    63.7   Customer Visit

# %%
df[df['STOP*']=='Fort Pierce']
# Out:
#         START_DATE*         END_DATE* CATEGORY*       START*        STOP*  \
# 0  01-01-2016 21:11  01-01-2016 21:17  Business  Fort Pierce  Fort Pierce
# 1  01-02-2016 01:25  01-02-2016 01:37  Business  Fort Pierce  Fort Pierce
# 2  01-02-2016 20:25  01-02-2016 20:38  Business  Fort Pierce  Fort Pierce
# 3  01-05-2016 17:31  01-05-2016 17:45  Business  Fort Pierce  Fort Pierce
#
#    MILES*         PURPOSE*
# 0     5.1   Meal/Entertain
# 1     5.0              NaN
# 2     4.8  Errand/Supplies
# 3     4.7          Meeting

# %%
# Find all in the DF where the Colomn "PURPOSE*" is "NaN"
df[df['PURPOSE*'].isnull()]
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 1     01-02-2016 01:25  01-02-2016 01:37  Business       Fort Pierce
# 32      1/19/2016 9:09    1/19/2016 9:23  Business       Whitebridge
# 85    02-09-2016 10:54  02-09-2016 11:07  Personal       Whitebridge
# 86    02-09-2016 11:43  02-09-2016 11:50  Personal        Northwoods
# 87    02-09-2016 13:36  02-09-2016 13:52  Personal        Tanglewood
# ...                ...               ...       ...               ...
# 1066  12/19/2016 14:37  12/19/2016 14:50  Business  Unknown Location
# 1069  12/19/2016 19:05  12/19/2016 19:17  Business         Islamabad
# 1071   12/20/2016 8:49   12/20/2016 9:24  Business  Unknown Location
# 1143  12/29/2016 20:53  12/29/2016 21:42  Business           Kar?chi
# 1155            Totals               NaN       NaN               NaN
#
#                     STOP*   MILES* PURPOSE*
# 1             Fort Pierce      5.0      NaN
# 32    Lake Wellingborough      7.2      NaN
# ...

# %%
# The main distinction between loc and iloc is:

# loc is label-based, which means that you have to specify rows and columns based on their row and column labels.
# iloc is integer position-based, so you have to specify rows and columns by their integer position values (0-based integer position).
# loc[row_label, column_label]
# iloc[row_position, column_position]

# %%
df.columns
# Out:
# Index(['START_DATE*', 'END_DATE*', 'CATEGORY*', 'START*', 'STOP*', 'MILES*',
#        'PURPOSE*'],
#       dtype='object')

# %%
df.loc[100,'STOP*'] # loc[row_label, column_label]
# Out:
# 'Cary'

# %%
df.iloc[100,4] #iloc[row_position, column_position]
# Out:
# 'Cary'

# %% [markdown]
# # MELT

# %%
# Create a simple dataframe

# importing pandas as pd
import pandas as pd

# creating a dataframe
df = pd.DataFrame({'Name': {0: 'John', 1: 'Bob', 2: 'Shiela'},
        'Course': {0: 'Masters', 1: 'Graduate', 2: 'Graduate'},
        'Age': {0: 27, 1: 23, 2: 21}})
df
# Out:
#      Name    Course  Age
# 0    John   Masters   27
# 1     Bob  Graduate   23
# 2  Shiela  Graduate   21

# %%
df.melt()
# Out:
#   variable     value
# 0     Name      John
# 1     Name       Bob
# 2     Name    Shiela
# 3   Course   Masters
# 4   Course  Graduate
# 5   Course  Graduate
# 6      Age        27
# 7      Age        23
# 8      Age        21

# %%
# multiple unpivot columns
pd.melt(df, id_vars =['Name'], value_vars =['Course', 'Age'])
# Out:
#      Name variable     value
# 0    John   Course   Masters
# 1     Bob   Course  Graduate
# 2  Shiela   Course  Graduate
# 3    John      Age        27
# 4     Bob      Age        23
# 5  Shiela      Age        21
